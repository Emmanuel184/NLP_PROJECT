# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/homedirel/ML/DATA/NLP_DATA/The-Office-Lines-V4.csv")

# %%
df.head(2)
# Out:
#    season  episode  title  scene  speaker  \
# 0       1        1  Pilot      1  Michael
# 1       1        1  Pilot      1      Jim
#
#                                                 line Unnamed: 6
# 0  All right Jim. Your quarterlies look very good...        NaN
# 1         Oh, I told you. I couldn't close it. So...        NaN

# %%
df["number_of_words"] = df["line"].str.strip().str.split(" ")

# %%
df["number_of_words"] = df["number_of_words"].apply(lambda x: len(x))

# %%
df["speaker"]
# Out:
#        season  episode   title  scene   speaker  \
# 0           1        1   Pilot      1   Michael
# 1           1        1   Pilot      1       Jim
# 2           1        1   Pilot      1   Michael
# 3           1        1   Pilot      1       Jim
# 4           1        1   Pilot      1   Michael
# ...       ...      ...     ...    ...       ...
# 54621       9       24  Finale   8153     Creed
# 54622       9       24  Finale   8154  Meredith
# 54623       9       24  Finale   8155   Phyllis
# 54624       9       24  Finale   8156       Jim
# 54625       9       24  Finale   8157       Pam
#
#                                                     line Unnamed: 6  \
# 0      All right Jim. Your quarterlies look very good...        NaN
# 1             Oh, I told you. I couldn't close it. So...        NaN
# 2      So you've come to the master for guidance? Is ...        NaN
# 3             Actually, you called me in here, but yeah.        NaN
# ...

# %%
dwight_lines = df[df['speaker'] == 'Dwight']

# %%
dwight_lines
# Out:
#        season  episode   title  scene speaker  \
# 16          1        1   Pilot      5  Dwight
# 21          1        1   Pilot      7  Dwight
# 23          1        1   Pilot      7  Dwight
# 85          1        1   Pilot     19  Dwight
# 87          1        1   Pilot     19  Dwight
# ...       ...      ...     ...    ...     ...
# 54582       9       24  Finale   8138  Dwight
# 54590       9       24  Finale   8140  Dwight
# 54592       9       24  Finale   8140  Dwight
# 54595       9       24  Finale   8140  Dwight
# 54597       9       24  Finale   8141  Dwight
#
#                                                     line Unnamed: 6  \
# 16      Shall I play for you? Pa rum pump um pum  I h...        NaN
# 21                                              Whassup!        NaN
# 23                                              Whassup.        NaN
# 85                                                 What?        NaN
# ...
